# %% [markdown]
# <a href="https://colab.research.google.com/github/motazsaad/Arabic-Propaganda-Detection-Research/blob/main/AugSamples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

SynonymAugDF = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/SynonymAug.csv')
ContextWordEmbsAugDF = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/ContextWordEmbsAug.csv')
BackTransAugDF = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/BackTransAug.csv')
originalDF = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/only_arabic.csv')
CorpsExpandDF= pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/CorpsExpand.csv') 
ContextWordEmbsSubAug_lessDF = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/ContextWordEmbsSubAug_less.csv') 
ContextWordEmbsAug_lessDF = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/ContextWordEmbsAug_less.csv') 
ContextWordEmbsSubAugDF = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/propaganda/augResults/ContextWordEmbsSubAug.csv')

# %%
originalDF['technique'].value_counts()
# Out:
# Loaded Language                                  446
# Name calling/Labeling                            244
# no technique                                      95
# Smears                                            85
# Appeal to fear/prejudice                          48
# Slogans                                           44
# Exaggeration/Minimisation                         44
# Doubt                                             29
# Glittering generalities (Virtue)                  25
# Appeal to authority                               21
# Obfuscation, Intentional vagueness, Confusion      9
# Repetition                                         9
# Thought-terminating cliché                         6
# Flag-waving                                        5
# Causal Oversimplification                          4
# Whataboutism                                       3
# Black-and-white Fallacy/Dictatorship               2
# Presenting Irrelevant Data (Red Herring)           1
# ...

# %%
SynonymAugDF['technique'].value_counts()
# Out:
# Loaded Language                                  251
# Name calling/Labeling                            198
# Smears                                           126
# no technique                                      95
# Appeal to authority                               83
# Appeal to fear/prejudice                          80
# Glittering generalities (Virtue)                  79
# Exaggeration/Minimisation                         59
# Doubt                                             36
# Slogans                                           31
# Obfuscation, Intentional vagueness, Confusion     12
# Repetition                                         8
# Black-and-white Fallacy/Dictatorship               8
# Flag-waving                                        7
# Thought-terminating cliché                         7
# Causal Oversimplification                          6
# Whataboutism                                       3
# Presenting Irrelevant Data (Red Herring)           1
# ...

# %%
ContextWordEmbsAugDF['technique'].value_counts()
# Out:
# Causal Oversimplification                        700
# Presenting Irrelevant Data (Red Herring)         700
# Appeal to authority                              699
# Smears                                           698
# Whataboutism                                     694
# Black-and-white Fallacy/Dictatorship             692
# Loaded Language                                  690
# Appeal to fear/prejudice                         684
# Name calling/Labeling                            679
# Glittering generalities (Virtue)                 674
# Doubt                                            668
# Obfuscation, Intentional vagueness, Confusion    640
# Exaggeration/Minimisation                        637
# Flag-waving                                      593
# Thought-terminating cliché                       527
# Slogans                                          484
# Repetition                                       405
# no technique                                      94
# ...

# %%
ContextWordEmbsSubAugDF['technique'].value_counts()
# Out:
# Causal Oversimplification                        700
# Presenting Irrelevant Data (Red Herring)         700
# Appeal to authority                              699
# Black-and-white Fallacy/Dictatorship             696
# Whataboutism                                     695
# Smears                                           693
# Appeal to fear/prejudice                         685
# Loaded Language                                  677
# Glittering generalities (Virtue)                 676
# Doubt                                            670
# Name calling/Labeling                            662
# Obfuscation, Intentional vagueness, Confusion    626
# Exaggeration/Minimisation                        623
# Flag-waving                                      584
# Thought-terminating cliché                       509
# Slogans                                          467
# Repetition                                       345
# no technique                                      95
# ...

# %%
BackTransAugDF['technique'].value_counts()
# Out:
# Loaded Language                                  353
# Name calling/Labeling                            227
# no technique                                      95
# Smears                                            85
# Appeal to fear/prejudice                          48
# Exaggeration/Minimisation                         44
# Slogans                                           37
# Doubt                                             29
# Glittering generalities (Virtue)                  25
# Appeal to authority                               21
# Obfuscation, Intentional vagueness, Confusion      9
# Repetition                                         8
# Thought-terminating cliché                         6
# Flag-waving                                        5
# Causal Oversimplification                          4
# Whataboutism                                       3
# Black-and-white Fallacy/Dictatorship               2
# Presenting Irrelevant Data (Red Herring)           1
# ...

# %%
CorpsExpandDF['technique'].value_counts()
# Out:
# no technique                                     34175
# Smears                                           16273
# Glittering generalities (Virtue)                 10924
# Appeal to authority                               8016
# Appeal to fear/prejudice                          4992
# Name calling/Labeling                             4187
# Doubt                                             3751
# Exaggeration/Minimisation                         1801
# Flag-waving                                       1607
# Loaded Language                                   1604
# Whataboutism                                       998
# Causal Oversimplification                          245
# Black-and-white Fallacy/Dictatorship               171
# Obfuscation, Intentional vagueness, Confusion       64
# Slogans                                             43
# Presenting Irrelevant Data (Red Herring)            27
# Name: technique, dtype: int64

# %%
ContextWordEmbsAug_lessDF['technique'].value_counts()
# Out:
# Causal Oversimplification                        697
# Presenting Irrelevant Data (Red Herring)         695
# Smears                                           693
# Loaded Language                                  692
# Appeal to authority                              687
# Name calling/Labeling                            677
# Glittering generalities (Virtue)                 671
# Appeal to fear/prejudice                         669
# Doubt                                            652
# Exaggeration/Minimisation                        634
# Flag-waving                                      594
# Obfuscation, Intentional vagueness, Confusion    584
# Whataboutism                                     514
# Slogans                                          493
# Thought-terminating cliché                       476
# Black-and-white Fallacy/Dictatorship             422
# Repetition                                       382
# no technique                                      95
# ...

# %%
ContextWordEmbsSubAugDF['technique'].value_counts()
# Out:
# Causal Oversimplification                        700
# Presenting Irrelevant Data (Red Herring)         700
# Appeal to authority                              699
# Black-and-white Fallacy/Dictatorship             696
# Whataboutism                                     695
# Smears                                           693
# Appeal to fear/prejudice                         685
# Loaded Language                                  677
# Glittering generalities (Virtue)                 676
# Doubt                                            670
# Name calling/Labeling                            662
# Obfuscation, Intentional vagueness, Confusion    626
# Exaggeration/Minimisation                        623
# Flag-waving                                      584
# Thought-terminating cliché                       509
# Slogans                                          467
# Repetition                                       345
# no technique                                      95
# ...

# %%
originalDF[originalDF.technique=='Causal Oversimplification']
# Out:
#      Unnamed: 0  start  end                  technique  \
# 435         435      0  154  Causal Oversimplification
# 453         453      8   68  Causal Oversimplification
# 518         518     30   75  Causal Oversimplification
# 569         569     15   76  Causal Oversimplification
#
#                                                   text  \
# 435  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...
# 453  مستقبل سيئ ينتظر البشرية الذكاء الاصطناعي في ق...
# 518      وقوع زلزال في خليج السويس بسبب النشع البترولي
# 569  حروب ونزاعات تنشأ حتى اليوم بسبب انكار تركيا ل...
#
#                                              full_text                   id  \
# 435  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...                 7300
# 453  خاص مستقبل سيئ ينتظر البشرية الذكاء الاصطناعي ...                 7309
# 518  البحوث الفلكية المصري يحذر من وقوع زلزال في خل...                 7333
# 569  بين سام وعمار حروب ونزاعات تنشأ حتى اليوم بسبب...  1389489981031206912
#
# ...

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Causal Oversimplification') & (SynonymAugDF['text'] =='أدى مشاركة الملايين من الهنود في مهرجان ديني هندوسي دون اتباع قواعد السلامة إلى استفحال تفشي كوفيد في البلاد وارتفاع حاد في عدد حالات الإصابة والوفيات')]
# Out:
#       Unnamed: 0                                          full_text  start  \
# 1084           0  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 1087           7  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 1089          70  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
#
#       end                  technique  \
# 1084  154  Causal Oversimplification
# 1087  154  Causal Oversimplification
# 1089  154  Causal Oversimplification
#
#                                                    text    id  start_new  \
# 1084  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...  7300        0.0
# 1087  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...  7300        0.0
# 1089  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...  7300        0.0
#
#       end_new                                     augmented_text  \
# 1084    150.0  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...
# 1087    150.0  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...
# ...

# %%
ContextWordEmbsAugDF.loc[(ContextWordEmbsAugDF['technique']=='Causal Oversimplification') & (ContextWordEmbsAugDF['text'] =='أدى مشاركة الملايين من الهنود في مهرجان ديني هندوسي دون اتباع قواعد السلامة إلى استفحال تفشي كوفيد في البلاد وارتفاع حاد في عدد حالات الإصابة والوفيات')]
# Out:
#        Unnamed: 0                                          full_text  start  \
# 10262           4  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10265           7  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10269          11  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10271          13  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10285          27  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# ...           ...                                                ...    ...
# 10948         690  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10949         691  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10950         692  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10951         693  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10953         695  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
#
#        end                  technique  \
# ...

# %%
BackTransAugDF.loc[(BackTransAugDF['technique']=='Causal Oversimplification') & (BackTransAugDF['text'] =='أدى مشاركة الملايين من الهنود في مهرجان ديني هندوسي دون اتباع قواعد السلامة إلى استفحال تفشي كوفيد في البلاد وارتفاع حاد في عدد حالات الإصابة والوفيات')]
# Out:
#       Unnamed: 0                                          full_text  start  \
# 1001           6  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
#
#       end                  technique  \
# 1001  154  Causal Oversimplification
#
#                                                    text    id  start_new  \
# 1001  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...  7300        0.0
#
#       end_new                                     augmented_text  \
# 1001    150.0  وقد أدت مشاركة الملايين من الهنود في مهرجان دي...
#
#                                     augmented_full_text
# 1001  وقد أدت مشاركة الملايين من الهنود في مهرجان دي...

# %%
CorpsExpandDF.loc[(CorpsExpandDF['technique']=='Causal Oversimplification') & (CorpsExpandDF['text'] =='أدى مشاركة الملايين من الهنود في مهرجان ديني هندوسي دون اتباع قواعد السلامة إلى استفحال تفشي كوفيد في البلاد وارتفاع حاد في عدد حالات الإصابة والوفيات')]
# Out:
#        Unnamed: 0                                          full_text  start  \
# 88851         223  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88852         224  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88853         225  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88854         226  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88855         227  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88856         228  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88857         229  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88858         230  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88859         231  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88860         232  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 88861         233  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# ...

# %%
ContextWordEmbsSubAug_lessDF.loc[(ContextWordEmbsSubAug_lessDF['technique']=='Causal Oversimplification') & (ContextWordEmbsSubAug_lessDF['text'] =='أدى مشاركة الملايين من الهنود في مهرجان ديني هندوسي دون اتباع قواعد السلامة إلى استفحال تفشي كوفيد في البلاد وارتفاع حاد في عدد حالات الإصابة والوفيات')]
# Out:
#        Unnamed: 0                                          full_text  start  \
# 9407            4  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9409            6  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9418           15  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9427           24  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9428           25  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# ...           ...                                                ...    ...
# 10082         681  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10085         684  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10087         686  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10090         689  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10095         694  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
#
#        end                  technique  \
# ...

# %%
ContextWordEmbsAug_lessDF.loc[(ContextWordEmbsAug_lessDF['technique']=='Causal Oversimplification') & (ContextWordEmbsAug_lessDF['text'] =='أدى مشاركة الملايين من الهنود في مهرجان ديني هندوسي دون اتباع قواعد السلامة إلى استفحال تفشي كوفيد في البلاد وارتفاع حاد في عدد حالات الإصابة والوفيات')]
# Out:
#        Unnamed: 0                                          full_text  start  \
# 9632            2  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9646           16  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9651           21  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9653           23  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 9656           26  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# ...           ...                                                ...    ...
# 10316         689  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10322         695  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10323         696  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10324         697  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10325         698  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
#
#        end                  technique  \
# ...

# %%
ContextWordEmbsSubAugDF.loc[(ContextWordEmbsSubAugDF['technique']=='Causal Oversimplification') & (ContextWordEmbsSubAugDF['text'] =='أدى مشاركة الملايين من الهنود في مهرجان ديني هندوسي دون اتباع قواعد السلامة إلى استفحال تفشي كوفيد في البلاد وارتفاع حاد في عدد حالات الإصابة والوفيات')]
# Out:
#        Unnamed: 0                                          full_text  start  \
# 10104           2  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10108           6  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10112          10  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10114          12  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10126          24  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# ...           ...                                                ...    ...
# 10787         685  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10788         686  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10793         691  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10800         698  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
# 10801         699  أدى مشاركة الملايين من الهنود في مهرجان ديني ه...      0
#
#        end                  technique  \
# ...

# %%
originalDF[originalDF.technique=='Presenting Irrelevant Data (Red Herring)']
# Out:
#      Unnamed: 0  start  end                                 technique  \
# 116         116      5   66  Presenting Irrelevant Data (Red Herring)
#
#                                                   text  \
# 116  شابة سعودية تقع في كارثة وتدهس جمعا من الناس ب...
#
#                                              full_text                   id  \
# 116  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...  1367143382750003203
#
#      start_new  end_new
# 116        5.0     66.0

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]
# Out:
#      Unnamed: 0                                          full_text  start  \
# 982           0  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
#
#      end                                 technique  \
# 982   66  Presenting Irrelevant Data (Red Herring)
#
#                                                   text                   id  \
# 982  شابة سعودية تقع في كارثة وتدهس جمعا من الناس ب...  1367143382750003203
#
#      start_new  end_new                                     augmented_text  \
# 982        5.0     66.0  شابة سعودية تقع في كارثة وتدهس جمعا من الناس ب...
#
#                                    augmented_full_text
# 982  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...

# %%
ContextWordEmbsAugDF.loc[(ContextWordEmbsAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]
# Out:
#       Unnamed: 0                                          full_text  start  \
# 6946           0  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6947           1  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6948           2  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6949           3  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6950           4  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# ...          ...                                                ...    ...
# 7641         695  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7642         696  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7643         697  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7644         698  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7645         699  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
#
#       end                                 technique  \
# ...

# %%
BackTransAugDF.loc[(BackTransAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]
# Out:
#      Unnamed: 0                                          full_text  start  \
# 965           0  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
#
#      end                                 technique  \
# 965   66  Presenting Irrelevant Data (Red Herring)
#
#                                                   text                   id  \
# 965  شابة سعودية تقع في كارثة وتدهس جمعا من الناس ب...  1367143382750003203
#
#      start_new  end_new                                     augmented_text  \
# 965        5.0     66.0  شابة سعودية في كارثة و حشد من الناس دهستهم سيا...
#
#                                    augmented_full_text
# 965  شاهد شابة سعودية في كارثة و حشد من الناس دهسته...

# %%
CorpsExpandDF.loc[(CorpsExpandDF['technique']=='Presenting Irrelevant Data (Red Herring)')]
# Out:
#        Unnamed: 0                                          full_text  start  \
# 79421           0  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79422           1  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79423           2  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79424           3  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79425           4  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79426           5  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79427           6  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79428           7  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79429           8  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79430           9  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 79431          10  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# ...

# %%
ContextWordEmbsSubAug_lessDF.loc[(ContextWordEmbsSubAug_lessDF['technique']=='Presenting Irrelevant Data (Red Herring)')]
# Out:
#       Unnamed: 0                                          full_text  start  \
# 6672           0  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6673           1  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6674           2  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6675           3  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6676           4  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# ...          ...                                                ...    ...
# 7356         695  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7357         696  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7358         697  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7359         698  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7360         699  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
#
#       end                                 technique  \
# ...

# %%
ContextWordEmbsAug_lessDF.loc[(ContextWordEmbsAug_lessDF['technique']=='Presenting Irrelevant Data (Red Herring)')]
# Out:
#       Unnamed: 0                                          full_text  start  \
# 6836           0  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6837           1  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6838           2  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6839           3  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6840           4  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# ...          ...                                                ...    ...
# 7526         695  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7527         696  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7528         697  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7529         698  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7530         699  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
#
#       end                                 technique  \
# ...

# %%
ContextWordEmbsSubAugDF.loc[(ContextWordEmbsSubAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]
# Out:
#       Unnamed: 0                                          full_text  start  \
# 6803           0  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6804           1  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6805           2  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6806           3  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 6807           4  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# ...          ...                                                ...    ...
# 7498         695  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7499         696  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7500         697  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7501         698  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
# 7502         699  شاهد شابة سعودية تقع في كارثة وتدهس جمعا من ال...      5
#
#       end                                 technique  \
# ...

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]

# %%
SynonymAugDF.loc[(SynonymAugDF['technique']=='Presenting Irrelevant Data (Red Herring)')]

# %%
# %cd /content/gdrive/MyDrive/Github/
# Out:
# /content/gdrive/MyDrive/Github

# %%
https://github.com/motazsaad/Arabic-Propaganda-Detection-Research.git

# %%
# !git clone https://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@github.com/motazsaad/Arabic-Propaganda-Detection-Research
# Out:
# Cloning into 'Arabic-Propaganda-Detection-Research'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.

# %%
# %cd Arabic-Propaganda-Detection-Research
# Out:
# /content/gdrive/MyDrive/Github/Arabic-Propaganda-Detection-Research

# %%
# %ls -a
# Out:
# .git/  .gitignore  LICENSE  README.md
