# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (from stanza) (2.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (1.26.4)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.5)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->stanza) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->stanza) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->stanza) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->stanza) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->stanza) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->stanza) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->stanza) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->stanza) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->stanza) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->stanza) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->stanza) (2024.2.0)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.9 MB/s eta 0:00:0000:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.2 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %%
# multilable text classification rnn + pos + ner using augmented dataset
import json
import pandas as pd
import re
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
import tensorflow as tf
from sklearn.metrics import classification_report, f1_score
import matplotlib.pyplot as plt
import stanza
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import os
import joblib
from tensorflow.keras.layers import TextVectorization


print("Downloading and initializing Stanza Arabic models...")
stanza.download('ar')
nlp = stanza.Pipeline('ar', processors='tokenize,pos,ner')

# 1. Data Loading
def load_and_preprocess(json_path, augment=False):
   
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    df = pd.DataFrame(data)

    # Extract techniques and clean text
    df["techniques"] = df["labels"].apply(lambda x: [label["technique"] for label in x])
    df["text"] = df["text"].apply(lambda x: re.sub(r"@\w+|https?://\S+|#[^\s]+", "", x))

    if augment:
        # Add simple augmentation for rare classes
        rare_tech = ['Appeal to authority', 'Obfuscation', 'Repetition']
        aug_samples = []
        for _, row in df[df["techniques"].apply(lambda x: any(t in x for t in rare_tech))].iterrows():
            aug_samples.append({
                "text": re.sub(r"(\w+)\s+", r"\1 \1 ", row["text"]),  # Simple repetition
                "techniques": row["techniques"]
            })
        df = pd.concat([df, pd.DataFrame(aug_samples)])

    return df

# 2. Arabic Text Cleaning
def clean_arabic_text(text):
    
    # Normalize different forms of Arabic letters
    text = re.sub(r"[إأآا]", "ا", text)
    text = re.sub(r"[ةه]", "ه", text)
    text = re.sub(r"[ىي]", "ي", text)
    text = re.sub(r"[ؤئ]", "ء", text)
    
    # Remove diacritics and tatweel
    text = re.sub(r'[\u064B-\u065F\u0670\u0640]', '', text)
    
    # Normalize punctuation
    text = re.sub(r'[؟!]', '.', text)  # Standardize sentence endings
    text = re.sub(r'[،؛]', ',', text)  # Standardize pauses
    
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# 3. Linguistic Feature Extraction
def extract_linguistic_features(texts):
    """Extract POS and NER features using Stanza"""
    pos_features = []
    ner_features = []
    
    for text in texts:
        try:
            doc = nlp(text)
            
            # POS features
            pos_tags = []
            for sentence in doc.sentences:
                for word in sentence.words:
                    pos_tags.append(word.pos)
            pos_features.append(" ".join(pos_tags))
            
            # NER features
            entities = []
            for ent in doc.entities:
                entities.append(f"{ent.type}_{ent.text}")
            ner_features.append(" ".join(entities))
        except:
            # Fallback if processing fails
            pos_features.append("")
            ner_features.append("")
    
    return pos_features, ner_features

def create_linguistic_embeddings(pos_texts, ner_texts, n_components=16):
    """
    Convert POS/NER texts to dense embeddings using TF-IDF + SVD
    """
    # POS embeddings
    pos_vectorizer = TfidfVectorizer(max_features=500)
    pos_tfidf = pos_vectorizer.fit_transform(pos_texts)
    
    # Dynamically adjust n_components for POS
    pos_n_components = min(n_components, pos_tfidf.shape[1] - 1) if pos_tfidf.shape[1] > 1 else 1
    pos_svd = TruncatedSVD(n_components=pos_n_components)
    pos_emb = pos_svd.fit_transform(pos_tfidf)
    
    # NER embeddings
    ner_vectorizer = TfidfVectorizer(max_features=250)
    ner_tfidf = ner_vectorizer.fit_transform(ner_texts)
    
    # Dynamically adjust n_components for NER
    ner_n_components = min(n_components, ner_tfidf.shape[1] - 1) if ner_tfidf.shape[1] > 1 else 1
    ner_svd = TruncatedSVD(n_components=ner_n_components)
    ner_emb = ner_svd.fit_transform(ner_tfidf)
    
    # Pad embeddings to ensure consistent dimensionality
    if pos_emb.shape[1] < n_components:
        pos_emb = np.pad(pos_emb, ((0, 0), (0, n_components - pos_emb.shape[1])))
    if ner_emb.shape[1] < n_components:
        ner_emb = np.pad(ner_emb, ((0, 0), (0, n_components - ner_emb.shape[1])))
    
    return pos_emb, ner_emb, pos_vectorizer, ner_vectorizer, pos_svd, ner_svd


# Load datasets
print("Loading and preprocessing datasets...")
train_df = load_and_preprocess("/kaggle/input/data-for-train-test/all_aug_for_test.json", augment=True)
test_df = load_and_preprocess("/kaggle/input/data-for-train-test/task2_test_gold_label_final_mod.json")


#4.Data Preparation
all_techniques = sorted(set(tech for sublist in train_df["techniques"] for tech in sublist))
mlb = MultiLabelBinarizer(classes=all_techniques)
mlb.fit(train_df["techniques"])

train_df["cleaned_text"] = train_df["text"].apply(clean_arabic_text)
test_df["cleaned_text"] = test_df["text"].apply(clean_arabic_text)

print("Extracting linguistic features for train and test...")
train_pos_raw, train_ner_raw = extract_linguistic_features(train_df["cleaned_text"])
test_pos_raw, test_ner_raw = extract_linguistic_features(test_df["cleaned_text"])


pos_vectorizer = TfidfVectorizer(max_features=500).fit(train_pos_raw)
train_pos_tfidf = pos_vectorizer.transform(train_pos_raw)
pos_svd = TruncatedSVD(n_components=min(16, train_pos_tfidf.shape[1] - 1), random_state=42).fit(train_pos_tfidf)

ner_vectorizer = TfidfVectorizer(max_features=250).fit(train_ner_raw)
train_ner_tfidf = ner_vectorizer.transform(train_ner_raw)
ner_svd = TruncatedSVD(n_components=min(16, train_ner_tfidf.shape[1] - 1), random_state=42).fit(train_ner_tfidf)


X_train_pos = pos_svd.transform(pos_vectorizer.transform(train_pos_raw))
X_train_ner = ner_svd.transform(ner_vectorizer.transform(train_ner_raw))

X_test_pos = pos_svd.transform(pos_vectorizer.transform(test_pos_raw))
X_test_ner = ner_svd.transform(ner_vectorizer.transform(test_ner_raw))

y_train_full = mlb.transform(train_df["techniques"])
y_test = mlb.transform(test_df["techniques"])



# 5. Train/Validation Split
test_size = 0.2
split_idx = int(len(train_df) * (1 - test_size))

X_train = {
    "text": train_df["cleaned_text"][:split_idx],
    "pos_features": X_train_pos[:split_idx],
    "ner_features": X_train_ner[:split_idx]
}
y_train = y_train_full[:split_idx]

X_val = {
    "text": train_df["cleaned_text"][split_idx:],
    "pos_features": X_train_pos[split_idx:],
    "ner_features": X_train_ner[split_idx:]
}
y_val = y_train_full[split_idx:]

X_test = {
    "text": test_df["cleaned_text"],
    "pos_features": X_test_pos,
    "ner_features": X_test_ner
}
y_test = y_test

# 6. Text Vectorization
max_tokens = 20000
max_length = 128

# Create text vectorization layer
vectorizer = TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length,
    standardize=None  
)

# Adapt the vectorizer to the training text
text_ds = tf.data.Dataset.from_tensor_slices(X_train["text"])
vectorizer.adapt(text_ds)

# Function to vectorize text
def vectorize_text(text):
    return vectorizer(text)

# 7. Custom Loss and Metrics
class AdaptiveFocalLoss(tf.keras.losses.Loss):
    """Adaptive Focal Loss for imbalanced multi-label classification"""
    def __init__(self, class_frequencies, gamma_base=2.0, alpha=0.25, name='adaptive_focal_loss'):
        super().__init__(name=name)
        self.class_frequencies = class_frequencies
        self.gamma_base = gamma_base
        self.alpha = alpha

        # Convert to tensor with proper dtype
        self.gamma = {i: tf.constant(gamma_base * (1 + (1 - freq)), dtype=tf.float32)
                     for i, freq in enumerate(class_frequencies)}
        self.alpha_tensor = tf.constant(alpha, dtype=tf.float32)

    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
        gamma_tensor = tf.zeros_like(y_true, dtype=tf.float32)

        for i in range(y_true.shape[1]):
            gamma_tensor = tf.where(
                tf.equal(y_true[:, i:i+1], 1),
                self.gamma[i],
                gamma_tensor
            )

        loss = -self.alpha_tensor * tf.pow(1.0 - pt, gamma_tensor) * tf.math.log(pt + 1e-7)
        return tf.reduce_mean(loss)

    def get_config(self):
        config = super().get_config()
        config.update({
            'class_frequencies': self.class_frequencies.tolist(),
            'gamma_base': self.gamma_base,
            'alpha': self.alpha
        })
        return config

    @classmethod
    def from_config(cls, config):
        config['class_frequencies'] = np.array(config['class_frequencies'])
        return cls(**config)

class F1MicroScore(tf.keras.metrics.Metric):
    """Custom F1 Micro Score metric"""
    def __init__(self, name='f1_micro', **kwargs):
        super().__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision(thresholds=0.5)
        self.recall = tf.keras.metrics.Recall(thresholds=0.5)

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + 1e-6))

    def reset_state(self):
        self.precision.reset_state()
        self.recall.reset_state()

# 8. RNN + Attention + LSTM Model Architecture
def build_rnn_attention_lstm_model():
    """Build model with RNN, Attention and LSTM layers"""
    # Text inputs
    text_input = tf.keras.layers.Input(shape=(1,), dtype=tf.string, name="text_input")
    
    # Linguistic feature inputs
    pos_input = tf.keras.layers.Input(shape=(16,), name="pos_features")
    ner_input = tf.keras.layers.Input(shape=(16,), name="ner_features")

    # Text processing pipeline
    # Vectorize text
    vectorized_text = vectorize_text(text_input)
    
    # Embedding layer
    embedding = tf.keras.layers.Embedding(
        input_dim=max_tokens,
        output_dim=128,
        mask_zero=True,
        name="embedding"
    )(vectorized_text)
    
    # RNN layers 
    rnn1 = tf.keras.layers.SimpleRNN(128, return_sequences=True)(embedding)
    rnn1 = tf.keras.layers.BatchNormalization()(rnn1)
    rnn1 = tf.keras.layers.Dropout(0.3)(rnn1)
    
    # Attention mechanism
    attention = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=64)(rnn1, rnn1)
    attention = tf.keras.layers.GlobalAveragePooling1D()(attention)
    
    # LSTM layer
    lstm = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True))(rnn1)
    lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm)
    
    # Process linguistic features
    pos_dense = tf.keras.layers.Dense(16, activation='swish')(pos_input)
    ner_dense = tf.keras.layers.Dense(16, activation='swish')(ner_input)
    
    # Concatenate all features
    combined = tf.keras.layers.concatenate([attention, lstm, pos_dense, ner_dense])
    
    # Dense layers
    dense1 = tf.keras.layers.Dense(256, activation='swish')(combined)
    dense1 = tf.keras.layers.BatchNormalization()(dense1)
    dense1 = tf.keras.layers.Dropout(0.3)(dense1)

    dense2 = tf.keras.layers.Dense(128, activation='swish')(dense1)
    dense2 = tf.keras.layers.BatchNormalization()(dense2)

    # Output with temperature scaling
    output = tf.keras.layers.Dense(len(all_techniques), activation="sigmoid")(dense2)
    
    return tf.keras.Model(
        inputs=[text_input, pos_input, ner_input], 
        outputs=output
    )

# 9. Training Configuration
# Calculate class weights
class_counts = y_train.sum(axis=0)
total_samples = len(y_train)
class_weights = total_samples / (len(class_counts) * (1 / (class_counts + 1e-6))) 
class_weights = {i: float(w) for i, w in enumerate(class_weights)}

# Apply special weights to important classes
special_weights = {
    'Obfuscation, Intentional vagueness, Confusion': 3.0,
    'Repetition': 2.5,
    'Appeal to authority': 2.0,
    'Glittering generalities (Virtue)': 2.0
}

for tech, weight in special_weights.items():
    if tech in all_techniques:
        class_weights[all_techniques.index(tech)] = weight

# Initialize focal loss
class_freq = y_train.mean(axis=0).values.astype(np.float32)
focal_loss = AdaptiveFocalLoss(class_freq)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_auc",
    patience=15,
    mode="max",
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-6
)

# 10. Model Training
print("Building and training model...")
model = build_rnn_attention_lstm_model()

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=focal_loss,
    metrics=[
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        F1MicroScore()
    ]
)

# Prepare the training data
train_data = {
    "text_input": np.array(X_train["text"]),
    "pos_features": np.array(X_train["pos_features"]),
    "ner_features": np.array(X_train["ner_features"])
}

val_data = {
    "text_input": np.array(X_val["text"]),
    "pos_features": np.array(X_val["pos_features"]),
    "ner_features": np.array(X_val["ner_features"])
}

test_data = {
    "text_input": np.array(X_test["text"]),
    "pos_features": np.array(X_test["pos_features"]),
    "ner_features": np.array(X_test["ner_features"])
}

history = model.fit(
    train_data,
    y_train,
    validation_data=(val_data, y_val),
    batch_size=64,
    epochs=50,
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights
)

# 11. Threshold Optimization
def optimize_thresholds(y_true, y_pred_probs):
    """Optimize prediction thresholds per class"""
    thresholds = []
    for i in range(y_pred_probs.shape[1]):
        if y_true[:, i].sum() == 0:
            thresholds.append(0.3)
            continue

        # Coarse search
        best_t, best_f1 = 0.3, 0
        for t in np.linspace(0.1, 0.5, 20):
            f1 = f1_score(y_true[:, i], y_pred_probs[:, i] > t, zero_division=0)
            if f1 > best_f1:
                best_t, best_f1 = t, f1

        # Fine search
        for t in np.linspace(max(0.1, best_t-0.05), min(0.5, best_t+0.05), 50):
            f1 = f1_score(y_true[:, i], y_pred_probs[:, i] > t, zero_division=0)
            if f1 > best_f1:
                best_t, best_f1 = t, f1
        thresholds.append(best_t)

    # Manual adjustments
    adjustments = {
        'Appeal to authority': 0.50,
        'Smears': 0.45,
        'Exaggeration/Minimisation': 0.45,
        'Flag-waving': 0.40,
        'Obfuscation, Intentional vagueness, Confusion': 0.35
    }
    for tech, thresh in adjustments.items():
        thresholds[all_techniques.index(tech)] = thresh

    return thresholds

val_pred_probs = model.predict(val_data)
optimal_thresholds = optimize_thresholds(y_val.values, val_pred_probs)

# 12. Hybrid Prediction with Rules
def apply_hybrid_rules(texts, pred_probs, thresholds):
    """Apply rule-based adjustments to model predictions"""
    arabic_rules = {
        'Appeal to authority': (
            r'(?:خبير|مختص|سلطة|توصية|بروفيسور|دكتور|عالم)(?:\s+\S+){0,3}\s+(?:قال|أكد|ذكر|صرح|أوضح|أشار)',
            0.65,
            0.6
        ),
        'Obfuscation, Intentional vagueness, Confusion': (
            r'(?:بعض|عديد|معظم|قطاع|أشخاص)\s+(?:من|منهم|لها)\b|\b(?:ربما|قد|يحتمل|يمكن|ربّما)\b|(?:قد يكون|من الممكن)',
            0.55,
            0.4
        ),
        'Repetition': (
            r'(\b\w+\b)(?:\W+\1){2,}|(?:نكرر|نؤكد|مرة أخرى|مرة أخرى)',
            0.5,
            0.4
        ),
        'Smears': (
            r'\b(?:فاسد|لص|سارق|نهب|خائن|عميل|خيانة)\b(?:\s+\S+){0,2}\s+\b(?:اتهام|اتهم|وصف|توصيف)',
            0.65,
            0.5
        ),
        'Flag-waving': (
            r'(?:وطن|أمة|شرف|انتماء|وطنية|قومية)\s+(?:فخر|تضحيات|دماء|واجب|مسؤولية)',
            0.7,
            0.5
        )
    }

    final_preds = np.zeros_like(pred_probs)
    tech_index = {tech:i for i, tech in enumerate(all_techniques)}

    for tech, (pattern, boost, max_thresh) in arabic_rules.items():
        i = tech_index[tech]
        compiled = re.compile(pattern)
        tech_thresh = min(thresholds[i] * boost, max_thresh)
        for j, text in enumerate(texts):
            if compiled.search(text):
                final_preds[j,i] = int(pred_probs[j,i] > tech_thresh)
            else:
                final_preds[j,i] = int(pred_probs[j,i] > thresholds[i])

    # Default thresholds for other classes
    for i, tech in enumerate(all_techniques):
        if tech not in arabic_rules:
            final_preds[:,i] = (pred_probs[:,i] > thresholds[i]).astype(int)

    # Ensure minimum one prediction per text
    for j in range(len(texts)):
        if not final_preds[j].any():
            final_preds[j,np.argmax(pred_probs[j])] = 1

    return final_preds

# 13. Final Evaluation
test_pred_probs = model.predict(test_data)
test_preds = apply_hybrid_rules(X_test["text"].tolist(), test_pred_probs, optimal_thresholds)

test_classes_present = [tech for tech in all_techniques if y_test[tech].sum() > 0]
test_class_indices = [all_techniques.index(tech) for tech in test_classes_present]

print("\nOptimized Thresholds:")
for tech, threshold in zip(all_techniques, optimal_thresholds):
    print(f"{tech:>50}: {threshold:.3f}")

print("\nEnhanced Test Performance with Linguistic Features:")
print(classification_report(
    y_test[test_classes_present],
    test_preds[:, test_class_indices],
    target_names=test_classes_present,
    zero_division=0
))

# Calculate and print F1-micro score
f1_micro = f1_score(y_test, test_preds, average='micro', zero_division=0)
print("F1-micro:", f1_micro)

# 14. Visualization
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history.history['precision'], label='Train Precision')
plt.plot(history.history['val_precision'], label='Val Precision')
plt.title('Precision')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Val Recall')
plt.title('Recall')
plt.legend()
plt.tight_layout()
plt.show()

# 15. Save Model
print("Saving model and metadata...")
model_save_path = "/models/propaganda_detector_cnn_attention_lstm"
os.makedirs(model_save_path, exist_ok=True)

# Save model
tf.keras.models.save_model(
    model,
    model_save_path,
    save_format='tf',
    include_optimizer=True
)

# Save metadata
metadata = {
    "mlb": mlb,
    "optimal_thresholds": optimal_thresholds,
    "all_techniques": all_techniques,
    "class_frequencies": class_freq,
    "vectorizer_vocab": vectorizer.get_vocabulary()
}
joblib.dump(metadata, f"{model_save_path}/metadata.pkl")

print("Training and evaluation complete!")
# Out:
# 2025-07-19 19:37:37.305992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752953857.510643      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752953857.572327      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Downloading and initializing Stanza Arabic models...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# Downloading https://huggingface.co/stanfordnlp/stanza-ar/resolve/v1.10.0/models/default.zip:   0%|          | …
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# Loading and preprocessing datasets...
# Preparing training data...
# Extracting linguistic features...
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['Glittering Generalities (Virtue)', 'Presenting Irrelevant Data (Red Herring)', 'Thought-terminating cliché', 'Whataboutism'] will be ignored
#   warnings.warn(
# Preparing test data...
# Extracting linguistic features...
# 2025-07-19 20:08:02.951399: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Building and training model...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - auc: 0.5651 - f1_micro: 0.2823 - loss: 13203.9150 - precision: 0.1897 - recall: 0.5527
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 56s 616ms/step - auc: 0.5659 - f1_micro: 0.2828 - loss: 13144.9082 - precision: 0.1901 - recall: 0.5530 - val_auc: 0.6201 - val_f1_micro: 0.3496 - val_loss: 0.0131 - val_precision: 0.6107 - val_recall: 0.2449 - learning_rate: 0.0010
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 31s 520ms/step - auc: 0.7840 - f1_micro: 0.4821 - loss: 4607.9448 - precision: 0.3954 - recall: 0.6208 - val_auc: 0.7548 - val_f1_micro: 0.2959 - val_loss: 0.0111 - val_precision: 0.5671 - val_recall: 0.2001 - learning_rate: 0.0010
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 455ms/step - auc: 0.9211 - f1_micro: 0.7045 - loss: 2708.8611 - precision: 0.6775 - recall: 0.7338 - val_auc: 0.7991 - val_f1_micro: 0.2959 - val_loss: 0.0111 - val_precision: 0.5671 - val_recall: 0.2001 - learning_rate: 0.0010
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 450ms/step - auc: 0.9674 - f1_micro: 0.8222 - loss: 1507.6589 - precision: 0.8189 - recall: 0.8256 - val_auc: 0.8716 - val_f1_micro: 0.3703 - val_loss: 0.0103 - val_precision: 0.6316 - val_recall: 0.2619 - learning_rate: 0.0010
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 451ms/step - auc: 0.9864 - f1_micro: 0.8931 - loss: 889.6699 - precision: 0.9056 - recall: 0.8810 - val_auc: 0.9222 - val_f1_micro: 0.5238 - val_loss: 0.0088 - val_precision: 0.7409 - val_recall: 0.4051 - learning_rate: 0.0010
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 452ms/step - auc: 0.9944 - f1_micro: 0.9371 - loss: 583.0136 - precision: 0.9438 - recall: 0.9305 - val_auc: 0.9638 - val_f1_micro: 0.6937 - val_loss: 0.0058 - val_precision: 0.8669 - val_recall: 0.5782 - learning_rate: 0.0010
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 41s 455ms/step - auc: 0.9974 - f1_micro: 0.9547 - loss: 402.2853 - precision: 0.9628 - recall: 0.9468 - val_auc: 0.9844 - val_f1_micro: 0.8395 - val_loss: 0.0038 - val_precision: 0.9371 - val_recall: 0.7603 - learning_rate: 0.0010
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 26s 437ms/step - auc: 0.9990 - f1_micro: 0.9712 - loss: 266.9470 - precision: 0.9799 - recall: 0.9626 - val_auc: 0.9900 - val_f1_micro: 0.9180 - val_loss: 0.0026 - val_precision: 0.9516 - val_recall: 0.8868 - learning_rate: 0.0010
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 444ms/step - auc: 0.9986 - f1_micro: 0.9791 - loss: 234.0071 - precision: 0.9824 - recall: 0.9758 - val_auc: 0.9894 - val_f1_micro: 0.9065 - val_loss: 0.0029 - val_precision: 0.9142 - val_recall: 0.8990 - learning_rate: 0.0010
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 457ms/step - auc: 0.9995 - f1_micro: 0.9830 - loss: 174.1206 - precision: 0.9858 - recall: 0.9802 - val_auc: 0.9969 - val_f1_micro: 0.9637 - val_loss: 0.0012 - val_precision: 0.9750 - val_recall: 0.9526 - learning_rate: 0.0010
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 453ms/step - auc: 0.9997 - f1_micro: 0.9866 - loss: 142.1284 - precision: 0.9910 - recall: 0.9823 - val_auc: 0.9962 - val_f1_micro: 0.9650 - val_loss: 0.0015 - val_precision: 0.9656 - val_recall: 0.9645 - learning_rate: 0.0010
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 442ms/step - auc: 0.9998 - f1_micro: 0.9894 - loss: 111.7134 - precision: 0.9918 - recall: 0.9869 - val_auc: 0.9968 - val_f1_micro: 0.9698 - val_loss: 0.0012 - val_precision: 0.9782 - val_recall: 0.9615 - learning_rate: 0.0010
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 443ms/step - auc: 0.9997 - f1_micro: 0.9916 - loss: 100.0596 - precision: 0.9941 - recall: 0.9892 - val_auc: 0.9967 - val_f1_micro: 0.9669 - val_loss: 0.0014 - val_precision: 0.9674 - val_recall: 0.9663 - learning_rate: 0.0010
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 457ms/step - auc: 0.9999 - f1_micro: 0.9927 - loss: 81.3355 - precision: 0.9934 - recall: 0.9920 - val_auc: 0.9966 - val_f1_micro: 0.9669 - val_loss: 0.0013 - val_precision: 0.9660 - val_recall: 0.9678 - learning_rate: 0.0010
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 455ms/step - auc: 0.9999 - f1_micro: 0.9924 - loss: 84.7914 - precision: 0.9954 - recall: 0.9894 - val_auc: 0.9969 - val_f1_micro: 0.9712 - val_loss: 0.0013 - val_precision: 0.9646 - val_recall: 0.9778 - learning_rate: 0.0010
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 26s 431ms/step - auc: 0.9999 - f1_micro: 0.9938 - loss: 74.3023 - precision: 0.9949 - recall: 0.9927 - val_auc: 0.9977 - val_f1_micro: 0.9783 - val_loss: 0.0010 - val_precision: 0.9814 - val_recall: 0.9752 - learning_rate: 2.0000e-04
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 469ms/step - auc: 0.9999 - f1_micro: 0.9963 - loss: 61.5728 - precision: 0.9975 - recall: 0.9952 - val_auc: 0.9980 - val_f1_micro: 0.9801 - val_loss: 9.1489e-04 - val_precision: 0.9836 - val_recall: 0.9767 - learning_rate: 2.0000e-04
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 452ms/step - auc: 1.0000 - f1_micro: 0.9967 - loss: 48.8705 - precision: 0.9982 - recall: 0.9953 - val_auc: 0.9978 - val_f1_micro: 0.9790 - val_loss: 9.3427e-04 - val_precision: 0.9832 - val_recall: 0.9748 - learning_rate: 2.0000e-04
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 26s 441ms/step - auc: 1.0000 - f1_micro: 0.9974 - loss: 42.8119 - precision: 0.9979 - recall: 0.9969 - val_auc: 0.9979 - val_f1_micro: 0.9797 - val_loss: 8.9965e-04 - val_precision: 0.9847 - val_recall: 0.9748 - learning_rate: 2.0000e-04
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 451ms/step - auc: 1.0000 - f1_micro: 0.9978 - loss: 41.5378 - precision: 0.9987 - recall: 0.9970 - val_auc: 0.9977 - val_f1_micro: 0.9799 - val_loss: 9.4088e-04 - val_precision: 0.9847 - val_recall: 0.9752 - learning_rate: 2.0000e-04
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 459ms/step - auc: 1.0000 - f1_micro: 0.9975 - loss: 37.5811 - precision: 0.9979 - recall: 0.9971 - val_auc: 0.9979 - val_f1_micro: 0.9807 - val_loss: 8.4440e-04 - val_precision: 0.9858 - val_recall: 0.9756 - learning_rate: 2.0000e-04
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 450ms/step - auc: 1.0000 - f1_micro: 0.9984 - loss: 35.5808 - precision: 0.9985 - recall: 0.9984 - val_auc: 0.9979 - val_f1_micro: 0.9814 - val_loss: 8.3423e-04 - val_precision: 0.9880 - val_recall: 0.9748 - learning_rate: 2.0000e-04
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 454ms/step - auc: 1.0000 - f1_micro: 0.9973 - loss: 35.7849 - precision: 0.9968 - recall: 0.9977 - val_auc: 0.9979 - val_f1_micro: 0.9816 - val_loss: 8.2311e-04 - val_precision: 0.9884 - val_recall: 0.9748 - learning_rate: 4.0000e-05
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 34s 573ms/step - auc: 1.0000 - f1_micro: 0.9986 - loss: 28.9329 - precision: 0.9990 - recall: 0.9982 - val_auc: 0.9979 - val_f1_micro: 0.9819 - val_loss: 8.2995e-04 - val_precision: 0.9884 - val_recall: 0.9756 - learning_rate: 4.0000e-05
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 453ms/step - auc: 1.0000 - f1_micro: 0.9980 - loss: 32.0104 - precision: 0.9985 - recall: 0.9976 - val_auc: 0.9979 - val_f1_micro: 0.9816 - val_loss: 8.3352e-04 - val_precision: 0.9880 - val_recall: 0.9752 - learning_rate: 4.0000e-05
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 456ms/step - auc: 1.0000 - f1_micro: 0.9985 - loss: 33.8919 - precision: 0.9995 - recall: 0.9976 - val_auc: 0.9979 - val_f1_micro: 0.9810 - val_loss: 8.3207e-04 - val_precision: 0.9873 - val_recall: 0.9748 - learning_rate: 4.0000e-05
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 450ms/step - auc: 1.0000 - f1_micro: 0.9972 - loss: 36.7578 - precision: 0.9986 - recall: 0.9958 - val_auc: 0.9979 - val_f1_micro: 0.9816 - val_loss: 8.3213e-04 - val_precision: 0.9884 - val_recall: 0.9748 - learning_rate: 4.0000e-05
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 28s 463ms/step - auc: 1.0000 - f1_micro: 0.9984 - loss: 33.1616 - precision: 0.9984 - recall: 0.9984 - val_auc: 0.9979 - val_f1_micro: 0.9818 - val_loss: 8.3269e-04 - val_precision: 0.9884 - val_recall: 0.9752 - learning_rate: 8.0000e-06
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 453ms/step - auc: 1.0000 - f1_micro: 0.9981 - loss: 31.0027 - precision: 0.9983 - recall: 0.9979 - val_auc: 0.9979 - val_f1_micro: 0.9814 - val_loss: 8.3248e-04 - val_precision: 0.9880 - val_recall: 0.9748 - learning_rate: 8.0000e-06
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 451ms/step - auc: 1.0000 - f1_micro: 0.9989 - loss: 29.4290 - precision: 0.9996 - recall: 0.9982 - val_auc: 0.9979 - val_f1_micro: 0.9818 - val_loss: 8.2674e-04 - val_precision: 0.9884 - val_recall: 0.9752 - learning_rate: 8.0000e-06
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 27s 443ms/step - auc: 1.0000 - f1_micro: 0.9978 - loss: 33.9641 - precision: 0.9987 - recall: 0.9969 - val_auc: 0.9979 - val_f1_micro: 0.9818 - val_loss: 8.2739e-04 - val_precision: 0.9884 - val_recall: 0.9752 - learning_rate: 8.0000e-06
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 26s 435ms/step - auc: 1.0000 - f1_micro: 0.9990 - loss: 27.3809 - precision: 0.9997 - recall: 0.9983 - val_auc: 0.9978 - val_f1_micro: 0.9816 - val_loss: 8.2997e-04 - val_precision: 0.9880 - val_recall: 0.9752 - learning_rate: 8.0000e-06
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
#
# Optimized Thresholds:
#                                Appeal to authority: 0.500
#                           Appeal to fear/prejudice: 0.479
#               Black-and-white Fallacy/Dictatorship: 0.500
#                          Causal Oversimplification: 0.395
#                                              Doubt: 0.445
#                          Exaggeration/Minimisation: 0.450
#                                        Flag-waving: 0.400
#                   Glittering generalities (Virtue): 0.500
#                                    Loaded Language: 0.445
#                              Name calling/Labeling: 0.332
#      Obfuscation, Intentional vagueness, Confusion: 0.350
#                                         Repetition: 0.395
#                                            Slogans: 0.500
#                                             Smears: 0.450
#
# Enhanced Test Performance with Linguistic Features:
#                                                precision    recall  f1-score   support
#
#                           Appeal to authority       1.00      1.00      1.00         1
#                      Appeal to fear/prejudice       0.31      0.17      0.22        24
#          Black-and-white Fallacy/Dictatorship       1.00      0.29      0.44         7
#                     Causal Oversimplification       0.50      0.25      0.33         4
#                                         Doubt       0.15      0.53      0.23        19
#                     Exaggeration/Minimisation       0.86      0.26      0.40        23
#                                   Flag-waving       0.83      0.56      0.67         9
#              Glittering generalities (Virtue)       0.33      1.00      0.50         1
#                               Loaded Language       0.75      0.70      0.73       220
#                         Name calling/Labeling       0.68      0.24      0.35       134
# Obfuscation, Intentional vagueness, Confusion       0.40      0.33      0.36         6
#                                    Repetition       0.67      0.67      0.67         3
#                                       Slogans       0.80      0.67      0.73         6
#                                        Smears       0.17      0.69      0.27        49
#
#                                     micro avg       0.46      0.51      0.48       506
#                                     macro avg       0.60      0.52      0.49       506
#                                  weighted avg       0.63      0.51      0.51       506
#                                   samples avg       0.44      0.42      0.40       506
#
# F1-micro: 0.48186046511627906
# Saving model and metadata...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_36/532071504.py in <cell line: 0>()
#     569
#     570 # Save model
# --> 571 tf.keras.models.save_model(
#     572     model,
#     573     model_save_path,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in save_model(model, filepath, overwrite, zipped, **kwargs)
#      67             )
#      68         else:
# ---> 69             raise ValueError(
#      70                 "The `save_format` argument is deprecated in Keras 3. "
#      71                 "Please remove this argument and pass a file path with "
#
# ValueError: The `save_format` argument is deprecated in Keras 3. Please remove this argument and pass a file path with either `.keras` or `.h5` extension.Received: save_format=tf

# %%
# multilable text classification rnn + pos + ner using original dataset
import json
import pandas as pd
import re
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
import tensorflow as tf
from sklearn.metrics import classification_report, f1_score
import matplotlib.pyplot as plt
import stanza
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import os
import joblib
from tensorflow.keras.layers import TextVectorization


print("Downloading and initializing Stanza Arabic models...")
stanza.download('ar')
nlp = stanza.Pipeline('ar', processors='tokenize,pos,ner')

# 1. Data Loading
def load_and_preprocess(json_path, augment=False):
   
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    df = pd.DataFrame(data)

    # Extract techniques and clean text
    df["techniques"] = df["labels"].apply(lambda x: [label["technique"] for label in x])
    df["text"] = df["text"].apply(lambda x: re.sub(r"@\w+|https?://\S+|#[^\s]+", "", x))

    if augment:
        # Add simple augmentation for rare classes
        rare_tech = ['Appeal to authority', 'Obfuscation', 'Repetition']
        aug_samples = []
        for _, row in df[df["techniques"].apply(lambda x: any(t in x for t in rare_tech))].iterrows():
            aug_samples.append({
                "text": re.sub(r"(\w+)\s+", r"\1 \1 ", row["text"]),  # Simple repetition
                "techniques": row["techniques"]
            })
        df = pd.concat([df, pd.DataFrame(aug_samples)])

    return df

# 2. Arabic Text Cleaning
def clean_arabic_text(text):
    
    # Normalize different forms of Arabic letters
    text = re.sub(r"[إأآا]", "ا", text)
    text = re.sub(r"[ةه]", "ه", text)
    text = re.sub(r"[ىي]", "ي", text)
    text = re.sub(r"[ؤئ]", "ء", text)
    
    # Remove diacritics and tatweel
    text = re.sub(r'[\u064B-\u065F\u0670\u0640]', '', text)
    
    # Normalize punctuation
    text = re.sub(r'[؟!]', '.', text)  # Standardize sentence endings
    text = re.sub(r'[،؛]', ',', text)  # Standardize pauses
    
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# 3. Linguistic Feature Extraction
def extract_linguistic_features(texts):
    """Extract POS and NER features using Stanza"""
    pos_features = []
    ner_features = []
    
    for text in texts:
        try:
            doc = nlp(text)
            
            # POS features
            pos_tags = []
            for sentence in doc.sentences:
                for word in sentence.words:
                    pos_tags.append(word.pos)
            pos_features.append(" ".join(pos_tags))
            
            # NER features
            entities = []
            for ent in doc.entities:
                entities.append(f"{ent.type}_{ent.text}")
            ner_features.append(" ".join(entities))
        except:
            # Fallback if processing fails
            pos_features.append("")
            ner_features.append("")
    
    return pos_features, ner_features

def create_linguistic_embeddings(pos_texts, ner_texts, n_components=16):
    """
    Convert POS/NER texts to dense embeddings using TF-IDF + SVD
    """
    # POS embeddings
    pos_vectorizer = TfidfVectorizer(max_features=500)
    pos_tfidf = pos_vectorizer.fit_transform(pos_texts)
    
    # Dynamically adjust n_components for POS
    pos_n_components = min(n_components, pos_tfidf.shape[1] - 1) if pos_tfidf.shape[1] > 1 else 1
    pos_svd = TruncatedSVD(n_components=pos_n_components)
    pos_emb = pos_svd.fit_transform(pos_tfidf)
    
    # NER embeddings
    ner_vectorizer = TfidfVectorizer(max_features=250)
    ner_tfidf = ner_vectorizer.fit_transform(ner_texts)
    
    # Dynamically adjust n_components for NER
    ner_n_components = min(n_components, ner_tfidf.shape[1] - 1) if ner_tfidf.shape[1] > 1 else 1
    ner_svd = TruncatedSVD(n_components=ner_n_components)
    ner_emb = ner_svd.fit_transform(ner_tfidf)
    
    # Pad embeddings to ensure consistent dimensionality
    if pos_emb.shape[1] < n_components:
        pos_emb = np.pad(pos_emb, ((0, 0), (0, n_components - pos_emb.shape[1])))
    if ner_emb.shape[1] < n_components:
        ner_emb = np.pad(ner_emb, ((0, 0), (0, n_components - ner_emb.shape[1])))
    
    return pos_emb, ner_emb, pos_vectorizer, ner_vectorizer, pos_svd, ner_svd


# Load datasets
print("Loading and preprocessing datasets...")
train_df = load_and_preprocess("/kaggle/input/data-for-train-test/task2_train.json", augment=True)
test_df = load_and_preprocess("/kaggle/input/data-for-train-test/task2_test_gold_label_final_mod.json")


#4.Data Preparation
all_techniques = sorted(set(tech for sublist in train_df["techniques"] for tech in sublist))
mlb = MultiLabelBinarizer(classes=all_techniques)
mlb.fit(train_df["techniques"])

train_df["cleaned_text"] = train_df["text"].apply(clean_arabic_text)
test_df["cleaned_text"] = test_df["text"].apply(clean_arabic_text)

print("Extracting linguistic features for train and test...")
train_pos_raw, train_ner_raw = extract_linguistic_features(train_df["cleaned_text"])
test_pos_raw, test_ner_raw = extract_linguistic_features(test_df["cleaned_text"])


pos_vectorizer = TfidfVectorizer(max_features=500).fit(train_pos_raw)
train_pos_tfidf = pos_vectorizer.transform(train_pos_raw)
pos_svd = TruncatedSVD(n_components=min(16, train_pos_tfidf.shape[1] - 1), random_state=42).fit(train_pos_tfidf)

ner_vectorizer = TfidfVectorizer(max_features=250).fit(train_ner_raw)
train_ner_tfidf = ner_vectorizer.transform(train_ner_raw)
ner_svd = TruncatedSVD(n_components=min(16, train_ner_tfidf.shape[1] - 1), random_state=42).fit(train_ner_tfidf)


X_train_pos = pos_svd.transform(pos_vectorizer.transform(train_pos_raw))
X_train_ner = ner_svd.transform(ner_vectorizer.transform(train_ner_raw))

X_test_pos = pos_svd.transform(pos_vectorizer.transform(test_pos_raw))
X_test_ner = ner_svd.transform(ner_vectorizer.transform(test_ner_raw))

y_train_full = mlb.transform(train_df["techniques"])
y_test = mlb.transform(test_df["techniques"])



# 5. Train/Validation Split
test_size = 0.2
split_idx = int(len(train_df) * (1 - test_size))

X_train = {
    "text": train_df["cleaned_text"][:split_idx],
    "pos_features": X_train_pos[:split_idx],
    "ner_features": X_train_ner[:split_idx]
}
y_train = y_train_full[:split_idx]

X_val = {
    "text": train_df["cleaned_text"][split_idx:],
    "pos_features": X_train_pos[split_idx:],
    "ner_features": X_train_ner[split_idx:]
}
y_val = y_train_full[split_idx:]

X_test = {
    "text": test_df["cleaned_text"],
    "pos_features": X_test_pos,
    "ner_features": X_test_ner
}
y_test = y_test

# 6. Text Vectorization
max_tokens = 20000
max_length = 128

# Create text vectorization layer
vectorizer = TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length,
    standardize=None  
)

# Adapt the vectorizer to the training text
text_ds = tf.data.Dataset.from_tensor_slices(X_train["text"])
vectorizer.adapt(text_ds)

# Function to vectorize text
def vectorize_text(text):
    return vectorizer(text)

# 7. Custom Loss and Metrics
class AdaptiveFocalLoss(tf.keras.losses.Loss):
    """Adaptive Focal Loss for imbalanced multi-label classification"""
    def __init__(self, class_frequencies, gamma_base=2.0, alpha=0.25, name='adaptive_focal_loss'):
        super().__init__(name=name)
        self.class_frequencies = class_frequencies
        self.gamma_base = gamma_base
        self.alpha = alpha

        # Convert to tensor with proper dtype
        self.gamma = {i: tf.constant(gamma_base * (1 + (1 - freq)), dtype=tf.float32)
                     for i, freq in enumerate(class_frequencies)}
        self.alpha_tensor = tf.constant(alpha, dtype=tf.float32)

    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
        gamma_tensor = tf.zeros_like(y_true, dtype=tf.float32)

        for i in range(y_true.shape[1]):
            gamma_tensor = tf.where(
                tf.equal(y_true[:, i:i+1], 1),
                self.gamma[i],
                gamma_tensor
            )

        loss = -self.alpha_tensor * tf.pow(1.0 - pt, gamma_tensor) * tf.math.log(pt + 1e-7)
        return tf.reduce_mean(loss)

    def get_config(self):
        config = super().get_config()
        config.update({
            'class_frequencies': self.class_frequencies.tolist(),
            'gamma_base': self.gamma_base,
            'alpha': self.alpha
        })
        return config

    @classmethod
    def from_config(cls, config):
        config['class_frequencies'] = np.array(config['class_frequencies'])
        return cls(**config)

class F1MicroScore(tf.keras.metrics.Metric):
    """Custom F1 Micro Score metric"""
    def __init__(self, name='f1_micro', **kwargs):
        super().__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision(thresholds=0.5)
        self.recall = tf.keras.metrics.Recall(thresholds=0.5)

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred)
        self.recall.update_state(y_true, y_pred)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + 1e-6))

    def reset_state(self):
        self.precision.reset_state()
        self.recall.reset_state()

# 8. RNN + Attention + LSTM Model Architecture
def build_rnn_attention_lstm_model():
    """Build model with RNN, Attention and LSTM layers"""
    # Text inputs
    text_input = tf.keras.layers.Input(shape=(1,), dtype=tf.string, name="text_input")
    
    # Linguistic feature inputs
    pos_input = tf.keras.layers.Input(shape=(16,), name="pos_features")
    ner_input = tf.keras.layers.Input(shape=(16,), name="ner_features")

    # Text processing pipeline
    # Vectorize text
    vectorized_text = vectorize_text(text_input)
    
    # Embedding layer
    embedding = tf.keras.layers.Embedding(
        input_dim=max_tokens,
        output_dim=128,
        mask_zero=True,
        name="embedding"
    )(vectorized_text)
    
    # RNN layers 
    rnn1 = tf.keras.layers.SimpleRNN(128, return_sequences=True)(embedding)
    rnn1 = tf.keras.layers.BatchNormalization()(rnn1)
    rnn1 = tf.keras.layers.Dropout(0.3)(rnn1)
    
    # Attention mechanism
    attention = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=64)(rnn1, rnn1)
    attention = tf.keras.layers.GlobalAveragePooling1D()(attention)
    
    # LSTM layer
    lstm = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True))(rnn1)
    lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm)
    
    # Process linguistic features
    pos_dense = tf.keras.layers.Dense(16, activation='swish')(pos_input)
    ner_dense = tf.keras.layers.Dense(16, activation='swish')(ner_input)
    
    # Concatenate all features
    combined = tf.keras.layers.concatenate([attention, lstm, pos_dense, ner_dense])
    
    # Dense layers
    dense1 = tf.keras.layers.Dense(256, activation='swish')(combined)
    dense1 = tf.keras.layers.BatchNormalization()(dense1)
    dense1 = tf.keras.layers.Dropout(0.3)(dense1)

    dense2 = tf.keras.layers.Dense(128, activation='swish')(dense1)
    dense2 = tf.keras.layers.BatchNormalization()(dense2)

    # Output with temperature scaling
    output = tf.keras.layers.Dense(len(all_techniques), activation="sigmoid")(dense2)
    
    return tf.keras.Model(
        inputs=[text_input, pos_input, ner_input], 
        outputs=output
    )

# 9. Training Configuration
# Calculate class weights
class_counts = y_train.sum(axis=0)
total_samples = len(y_train)
class_weights = total_samples / (len(class_counts) * (1 / (class_counts + 1e-6))) 
class_weights = {i: float(w) for i, w in enumerate(class_weights)}

# Apply special weights to important classes
special_weights = {
    'Obfuscation, Intentional vagueness, Confusion': 3.0,
    'Repetition': 2.5,
    'Appeal to authority': 2.0,
    'Glittering generalities (Virtue)': 2.0
}

for tech, weight in special_weights.items():
    if tech in all_techniques:
        class_weights[all_techniques.index(tech)] = weight

# Initialize focal loss
class_freq = y_train.mean(axis=0).values.astype(np.float32)
focal_loss = AdaptiveFocalLoss(class_freq)

# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_auc",
    patience=15,
    mode="max",
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-6
)

# 10. Model Training
print("Building and training model...")
model = build_rnn_attention_lstm_model()

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=focal_loss,
    metrics=[
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        F1MicroScore()
    ]
)

# Prepare the training data
train_data = {
    "text_input": np.array(X_train["text"]),
    "pos_features": np.array(X_train["pos_features"]),
    "ner_features": np.array(X_train["ner_features"])
}

val_data = {
    "text_input": np.array(X_val["text"]),
    "pos_features": np.array(X_val["pos_features"]),
    "ner_features": np.array(X_val["ner_features"])
}

test_data = {
    "text_input": np.array(X_test["text"]),
    "pos_features": np.array(X_test["pos_features"]),
    "ner_features": np.array(X_test["ner_features"])
}

history = model.fit(
    train_data,
    y_train,
    validation_data=(val_data, y_val),
    batch_size=64,
    epochs=50,
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights
)

# 11. Threshold Optimization
def optimize_thresholds(y_true, y_pred_probs):
    """Optimize prediction thresholds per class"""
    thresholds = []
    for i in range(y_pred_probs.shape[1]):
        if y_true[:, i].sum() == 0:
            thresholds.append(0.3)
            continue

        # Coarse search
        best_t, best_f1 = 0.3, 0
        for t in np.linspace(0.1, 0.5, 20):
            f1 = f1_score(y_true[:, i], y_pred_probs[:, i] > t, zero_division=0)
            if f1 > best_f1:
                best_t, best_f1 = t, f1

        # Fine search
        for t in np.linspace(max(0.1, best_t-0.05), min(0.5, best_t+0.05), 50):
            f1 = f1_score(y_true[:, i], y_pred_probs[:, i] > t, zero_division=0)
            if f1 > best_f1:
                best_t, best_f1 = t, f1
        thresholds.append(best_t)

    # Manual adjustments
    adjustments = {
        'Appeal to authority': 0.50,
        'Smears': 0.45,
        'Exaggeration/Minimisation': 0.45,
        'Flag-waving': 0.40,
        'Obfuscation, Intentional vagueness, Confusion': 0.35
    }
    for tech, thresh in adjustments.items():
        thresholds[all_techniques.index(tech)] = thresh

    return thresholds

val_pred_probs = model.predict(val_data)
optimal_thresholds = optimize_thresholds(y_val.values, val_pred_probs)

# 12. Hybrid Prediction with Rules
def apply_hybrid_rules(texts, pred_probs, thresholds):
    """Apply rule-based adjustments to model predictions"""
    arabic_rules = {
        'Appeal to authority': (
            r'(?:خبير|مختص|سلطة|توصية|بروفيسور|دكتور|عالم)(?:\s+\S+){0,3}\s+(?:قال|أكد|ذكر|صرح|أوضح|أشار)',
            0.65,
            0.6
        ),
        'Obfuscation, Intentional vagueness, Confusion': (
            r'(?:بعض|عديد|معظم|قطاع|أشخاص)\s+(?:من|منهم|لها)\b|\b(?:ربما|قد|يحتمل|يمكن|ربّما)\b|(?:قد يكون|من الممكن)',
            0.55,
            0.4
        ),
        'Repetition': (
            r'(\b\w+\b)(?:\W+\1){2,}|(?:نكرر|نؤكد|مرة أخرى|مرة أخرى)',
            0.5,
            0.4
        ),
        'Smears': (
            r'\b(?:فاسد|لص|سارق|نهب|خائن|عميل|خيانة)\b(?:\s+\S+){0,2}\s+\b(?:اتهام|اتهم|وصف|توصيف)',
            0.65,
            0.5
        ),
        'Flag-waving': (
            r'(?:وطن|أمة|شرف|انتماء|وطنية|قومية)\s+(?:فخر|تضحيات|دماء|واجب|مسؤولية)',
            0.7,
            0.5
        )
    }

    final_preds = np.zeros_like(pred_probs)
    tech_index = {tech:i for i, tech in enumerate(all_techniques)}

    for tech, (pattern, boost, max_thresh) in arabic_rules.items():
        i = tech_index[tech]
        compiled = re.compile(pattern)
        tech_thresh = min(thresholds[i] * boost, max_thresh)
        for j, text in enumerate(texts):
            if compiled.search(text):
                final_preds[j,i] = int(pred_probs[j,i] > tech_thresh)
            else:
                final_preds[j,i] = int(pred_probs[j,i] > thresholds[i])

    # Default thresholds for other classes
    for i, tech in enumerate(all_techniques):
        if tech not in arabic_rules:
            final_preds[:,i] = (pred_probs[:,i] > thresholds[i]).astype(int)

    # Ensure minimum one prediction per text
    for j in range(len(texts)):
        if not final_preds[j].any():
            final_preds[j,np.argmax(pred_probs[j])] = 1

    return final_preds

# 13. Final Evaluation
test_pred_probs = model.predict(test_data)
test_preds = apply_hybrid_rules(X_test["text"].tolist(), test_pred_probs, optimal_thresholds)

test_classes_present = [tech for tech in all_techniques if y_test[tech].sum() > 0]
test_class_indices = [all_techniques.index(tech) for tech in test_classes_present]

print("\nOptimized Thresholds:")
for tech, threshold in zip(all_techniques, optimal_thresholds):
    print(f"{tech:>50}: {threshold:.3f}")

print("\nEnhanced Test Performance with Linguistic Features:")
print(classification_report(
    y_test[test_classes_present],
    test_preds[:, test_class_indices],
    target_names=test_classes_present,
    zero_division=0
))

# Calculate and print F1-micro score
f1_micro = f1_score(y_test, test_preds, average='micro', zero_division=0)
print("F1-micro:", f1_micro)

# 14. Visualization
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history.history['precision'], label='Train Precision')
plt.plot(history.history['val_precision'], label='Val Precision')
plt.title('Precision')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Val Recall')
plt.title('Recall')
plt.legend()
plt.tight_layout()
plt.show()

# 15. Save Model
print("Saving model and metadata...")
model_save_path = "/models/propaganda_detector_cnn_attention_lstm"
os.makedirs(model_save_path, exist_ok=True)

# Save model
tf.keras.models.save_model(
    model,
    model_save_path,
    save_format='tf',
    include_optimizer=True
)

# Save metadata
metadata = {
    "mlb": mlb,
    "optimal_thresholds": optimal_thresholds,
    "all_techniques": all_techniques,
    "class_frequencies": class_freq,
    "vectorizer_vocab": vectorizer.get_vocabulary()
}
joblib.dump(metadata, f"{model_save_path}/metadata.pkl")

print("Training and evaluation complete!")
# Out:
# Downloading and initializing Stanza Arabic models...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# Loading and preprocessing datasets...
# Preparing training data...
# Extracting linguistic features...
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_label.py:895: UserWarning: unknown class(es) ['Presenting Irrelevant Data (Red Herring)', 'Thought-terminating cliché', 'Whataboutism'] will be ignored
#   warnings.warn(
# Preparing test data...
# Extracting linguistic features...
# Building and training model...
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d_1' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d_1' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - auc: 0.4849 - f1_micro: 0.1740 - loss: 390.8645 - precision: 0.1055 - recall: 0.4971
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'global_max_pooling1d_1' (of type GlobalMaxPooling1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 24s 975ms/step - auc: 0.4868 - f1_micro: 0.1750 - loss: 388.2859 - precision: 0.1061 - recall: 0.4989 - val_auc: 0.7227 - val_f1_micro: 0.3592 - val_loss: 0.0305 - val_precision: 0.2541 - val_recall: 0.6127 - learning_rate: 0.0010
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 433ms/step - auc: 0.5886 - f1_micro: 0.2217 - loss: 286.6603 - precision: 0.1364 - recall: 0.5916 - val_auc: 0.7624 - val_f1_micro: 0.3704 - val_loss: 0.0295 - val_precision: 0.2703 - val_recall: 0.5882 - learning_rate: 0.0010
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 431ms/step - auc: 0.6228 - f1_micro: 0.2330 - loss: 240.0253 - precision: 0.1431 - recall: 0.6265 - val_auc: 0.7645 - val_f1_micro: 0.3773 - val_loss: 0.0287 - val_precision: 0.2746 - val_recall: 0.6029 - learning_rate: 0.0010
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 427ms/step - auc: 0.6758 - f1_micro: 0.2574 - loss: 202.7028 - precision: 0.1595 - recall: 0.6662 - val_auc: 0.7603 - val_f1_micro: 0.3937 - val_loss: 0.0281 - val_precision: 0.2911 - val_recall: 0.6078 - learning_rate: 0.0010
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 431ms/step - auc: 0.7546 - f1_micro: 0.2926 - loss: 185.3520 - precision: 0.1806 - recall: 0.7710 - val_auc: 0.7681 - val_f1_micro: 0.4035 - val_loss: 0.0277 - val_precision: 0.3158 - val_recall: 0.5588 - learning_rate: 0.0010
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 504ms/step - auc: 0.7763 - f1_micro: 0.3175 - loss: 148.2031 - precision: 0.1990 - recall: 0.7849 - val_auc: 0.7726 - val_f1_micro: 0.4178 - val_loss: 0.0274 - val_precision: 0.3450 - val_recall: 0.5294 - learning_rate: 0.0010
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 430ms/step - auc: 0.8118 - f1_micro: 0.3202 - loss: 133.0168 - precision: 0.1979 - recall: 0.8412 - val_auc: 0.7757 - val_f1_micro: 0.3737 - val_loss: 0.0270 - val_precision: 0.3296 - val_recall: 0.4314 - learning_rate: 0.0010
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 432ms/step - auc: 0.8413 - f1_micro: 0.3234 - loss: 126.2031 - precision: 0.1986 - recall: 0.8714 - val_auc: 0.7870 - val_f1_micro: 0.4148 - val_loss: 0.0265 - val_precision: 0.3740 - val_recall: 0.4657 - learning_rate: 0.0010
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 447ms/step - auc: 0.8735 - f1_micro: 0.3587 - loss: 100.0510 - precision: 0.2250 - recall: 0.8847 - val_auc: 0.7933 - val_f1_micro: 0.4389 - val_loss: 0.0257 - val_precision: 0.5064 - val_recall: 0.3873 - learning_rate: 0.0010
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 440ms/step - auc: 0.8831 - f1_micro: 0.3616 - loss: 97.6053 - precision: 0.2268 - recall: 0.8925 - val_auc: 0.7933 - val_f1_micro: 0.4438 - val_loss: 0.0252 - val_precision: 0.5197 - val_recall: 0.3873 - learning_rate: 0.0010
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 433ms/step - auc: 0.8836 - f1_micro: 0.3827 - loss: 89.4773 - precision: 0.2450 - recall: 0.8756 - val_auc: 0.7850 - val_f1_micro: 0.4198 - val_loss: 0.0244 - val_precision: 0.5667 - val_recall: 0.3333 - learning_rate: 0.0010
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 419ms/step - auc: 0.9075 - f1_micro: 0.4132 - loss: 81.3466 - precision: 0.2708 - recall: 0.8719 - val_auc: 0.7875 - val_f1_micro: 0.4187 - val_loss: 0.0235 - val_precision: 0.5776 - val_recall: 0.3284 - learning_rate: 0.0010
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 433ms/step - auc: 0.9015 - f1_micro: 0.4099 - loss: 79.8576 - precision: 0.2671 - recall: 0.8811 - val_auc: 0.7765 - val_f1_micro: 0.4063 - val_loss: 0.0229 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 437ms/step - auc: 0.9287 - f1_micro: 0.4788 - loss: 71.1392 - precision: 0.3271 - recall: 0.8938 - val_auc: 0.7768 - val_f1_micro: 0.4063 - val_loss: 0.0223 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 442ms/step - auc: 0.9271 - f1_micro: 0.5201 - loss: 60.3530 - precision: 0.3719 - recall: 0.8654 - val_auc: 0.7776 - val_f1_micro: 0.4063 - val_loss: 0.0215 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 495ms/step - auc: 0.9452 - f1_micro: 0.5552 - loss: 57.6254 - precision: 0.4058 - recall: 0.8802 - val_auc: 0.7876 - val_f1_micro: 0.4063 - val_loss: 0.0208 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 440ms/step - auc: 0.9407 - f1_micro: 0.5930 - loss: 50.1230 - precision: 0.4537 - recall: 0.8576 - val_auc: 0.7834 - val_f1_micro: 0.4063 - val_loss: 0.0203 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 449ms/step - auc: 0.9538 - f1_micro: 0.6333 - loss: 44.5555 - precision: 0.4970 - recall: 0.8733 - val_auc: 0.7840 - val_f1_micro: 0.4063 - val_loss: 0.0198 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 431ms/step - auc: 0.9474 - f1_micro: 0.6537 - loss: 42.1552 - precision: 0.5417 - recall: 0.8246 - val_auc: 0.7764 - val_f1_micro: 0.4063 - val_loss: 0.0193 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 452ms/step - auc: 0.9518 - f1_micro: 0.6702 - loss: 36.8113 - precision: 0.5634 - recall: 0.8309 - val_auc: 0.7788 - val_f1_micro: 0.4063 - val_loss: 0.0190 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - auc: 0.9664 - f1_micro: 0.7013 - loss: 31.6030 - precision: 0.6073 - recall: 0.8306 - val_auc: 0.7808 - val_f1_micro: 0.4114 - val_loss: 0.0188 - val_precision: 0.5804 - val_recall: 0.3186 - learning_rate: 0.0010
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 423ms/step - auc: 0.9678 - f1_micro: 0.7533 - loss: 26.8699 - precision: 0.6918 - recall: 0.8276 - val_auc: 0.7830 - val_f1_micro: 0.4114 - val_loss: 0.0185 - val_precision: 0.5804 - val_recall: 0.3186 - learning_rate: 0.0010
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 433ms/step - auc: 0.9610 - f1_micro: 0.7529 - loss: 27.3035 - precision: 0.7066 - recall: 0.8092 - val_auc: 0.7769 - val_f1_micro: 0.4063 - val_loss: 0.0184 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - auc: 0.9775 - f1_micro: 0.8001 - loss: 23.8912 - precision: 0.7763 - recall: 0.8256 - val_auc: 0.7833 - val_f1_micro: 0.4063 - val_loss: 0.0183 - val_precision: 0.5766 - val_recall: 0.3137 - learning_rate: 0.0010
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 438ms/step - auc: 0.9789 - f1_micro: 0.8103 - loss: 21.1472 - precision: 0.7849 - recall: 0.8387 - val_auc: 0.7834 - val_f1_micro: 0.4076 - val_loss: 0.0183 - val_precision: 0.5818 - val_recall: 0.3137 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 435ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
#
# Optimized Thresholds:
#                                Appeal to authority: 0.500
#                           Appeal to fear/prejudice: 0.100
#               Black-and-white Fallacy/Dictatorship: 0.474
#                          Causal Oversimplification: 0.437
#                                              Doubt: 0.100
#                          Exaggeration/Minimisation: 0.450
#                                        Flag-waving: 0.400
#                   Glittering generalities (Virtue): 0.461
#                                    Loaded Language: 0.100
#                              Name calling/Labeling: 0.490
#      Obfuscation, Intentional vagueness, Confusion: 0.350
#                                         Repetition: 0.458
#                                            Slogans: 0.464
#                                             Smears: 0.450
#
# Enhanced Test Performance with Linguistic Features:
#                                                precision    recall  f1-score   support
#
#                           Appeal to authority       0.00      0.00      0.00         1
#                      Appeal to fear/prejudice       0.07      1.00      0.14        24
#          Black-and-white Fallacy/Dictatorship       0.00      0.00      0.00         7
#                     Causal Oversimplification       0.00      0.00      0.00         4
#                                         Doubt       0.06      1.00      0.11        19
#                     Exaggeration/Minimisation       0.07      1.00      0.13        23
#                                   Flag-waving       0.02      0.78      0.05         9
#              Glittering generalities (Virtue)       0.00      0.00      0.00         1
#                               Loaded Language       0.68      1.00      0.81       220
#                         Name calling/Labeling       0.53      0.46      0.50       134
# Obfuscation, Intentional vagueness, Confusion       0.02      1.00      0.04         6
#                                    Repetition       0.04      0.33      0.08         3
#                                       Slogans       0.02      0.83      0.04         6
#                                        Smears       0.15      1.00      0.26        49
#
#                                     micro avg       0.16      0.82      0.27       506
#                                     macro avg       0.12      0.60      0.15       506
#                                  weighted avg       0.46      0.82      0.53       506
#                                   samples avg       0.16      0.72      0.25       506
#
# F1-micro: 0.26615483045425464
# Saving model and metadata...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_36/3407927629.py in <cell line: 0>()
#     569
#     570 # Save model
# --> 571 tf.keras.models.save_model(
#     572     model,
#     573     model_save_path,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in save_model(model, filepath, overwrite, zipped, **kwargs)
#      67             )
#      68         else:
# ---> 69             raise ValueError(
#      70                 "The `save_format` argument is deprecated in Keras 3. "
#      71                 "Please remove this argument and pass a file path with "
#
# ValueError: The `save_format` argument is deprecated in Keras 3. Please remove this argument and pass a file path with either `.keras` or `.h5` extension.Received: save_format=tf
